# %%
# READ IN CSV FILES
import pandas as pd
import numpy as np

# %%
calendar_df = pd.read_csv('calendar.csv')
listings_df = pd.read_csv('listings.csv')
reviews_df = pd.read_csv('reviews.csv')

# %% [markdown]
# # Calendar Data frame

# %%
# SHOW ALL COLUMNS FOR CALENDAR

for i in calendar_df.columns:
    print(i)
# Out:
# listing_id
# date
# available
# price
# adjusted_price
# minimum_nights
# maximum_nights

# %%
calendar_df.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price              object
# adjusted_price     object
# minimum_nights    float64
# maximum_nights    float64
# dtype: object

# %% [markdown]
# # Listings Data frame

# %%
# SHOW ALL COLUMNS FOR LISTINGS

for i in listings_df.columns:
    print(i)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# ...

# %%
listings_df.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# name                                             object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 74, dtype: object

# %%
# THIS SHOWS THE ARRAY OF AMMENITIES FOR EACH ROW

test = listings_df['amenities']

# %%
test
# Out:
# 0       ["TV", "Refrigerator", "Wifi", "Free parking o...
# 1       ["Carbon monoxide alarm", "TV", "Backyard", "B...
# 2       ["Wifi", "Dryer", "Free parking on premises", ...
# 3       ["Refrigerator", "Wifi", "Dryer", "Free parkin...
# 4       ["Refrigerator", "Wifi", "Dryer", "Free parkin...
#                               ...
# 3915    ["TV", "Refrigerator", "Wifi", "Hangers", "Ext...
# 3916    ["TV", "Refrigerator", "Wifi", "Hangers", "Ext...
# 3917    ["TV", "Refrigerator", "Wifi", "Dryer", "Hange...
# 3918    ["TV", "Refrigerator", "Wifi", "Dryer", "Ceili...
# 3919    ["Carbon monoxide alarm", "Kitchen", "Private ...
# Name: amenities, Length: 3920, dtype: object

# %%
# THIS SHOWS A FULL LIST OF AMENITIES 
# MAYBE WE CAN CHOOSE A COUPLE?
amenities_list = list(listings_df.amenities)
amenities_list_string = " ".join(amenities_list)
amenities_list_string = amenities_list_string.replace('{', '')
amenities_list_string = amenities_list_string.replace('}', ',')
amenities_list_string = amenities_list_string.replace('"', '')
amenities_set = [x.strip() for x in amenities_list_string.split(',')]
amenities_set = set(amenities_set)
amenities_set
# Out:
# {'Private hot tub] [Rice maker',
#  'and table',
#  'Loreal',
#  'Public Goods conditioner',
#  'Toaster',
#  'Nexxus shampoo',
#  '45\\ HDTV',
#  'Breakfast',
#  'Lockbox] [Safe',
#  'Method body soap',
#  'Smoke alarm] [Outdoor dining area',
#  'Dove  body soap',
#  'Mid-sized  with freezer space refrigerator',
#  'Hotel size provided conditioner] [TV',
#  'generic  body soap',
#  'Travel conditioner',
#  'Liquid soap body soap',
#  'Amazon Echo and bluetooth speakers Bluetooth sound system',
#  'Wifi \\u2013 195 Mbps',
#  'Dial - liquid body soap',
#  'Sonos sound system',
#  'Dedicated workspace: table',
#  'walk-in closet',
#  'Wifi \\u2013 642 Mbps',
#  'Frigidaire  stainless steel electric stove',
#  'Avanti stainless steel electric stove',
#  'First aid kit',
#  'Custom Stereo sound system with Bluetooth and aux',
#  'Regular conditioner',
#  'Wifi \\u2013 600 Mbps',
#  'Wifi \\u2013 750 Mbps',
#  '32\\ TV',
#  'Wifi \\u2013 107 Mbps',
# ...

# %% [markdown]
# # Reviews Data frame

# %%
for i in reviews_df.columns:
    print(i)
# Out:
# listing_id
# id
# date
# reviewer_id
# reviewer_name
# comments

# %%
reviews_df.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object
